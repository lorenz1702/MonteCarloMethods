# %% [markdown]
# # Exercise:
# Use the simple model discussed in the lecture and implement the
# corresponding Markov chain; plot the resulting probability
# distribution

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %%
obser = pd.read_csv('observable.csv',header=None)
plt.scatter(obser[0],obser[1])
plt.xlabel('Number of chain')  # Label for the x-axis
plt.ylabel('Observable Value')  # Label for the y-axis
plt.grid()  # Optional: add grid for better visualization
plt.show()  # Display the plot
